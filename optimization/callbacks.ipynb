# %% [markdown]
# ## Data prep and modeling

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import tensorflow_datasets as tfds

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Layer
from tensorflow.keras.layers import InputLayer, Conv2D, MaxPool2D, Flatten, Dense, BatchNormalization, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.metrics import BinaryAccuracy, FalsePositives, FalseNegatives, TruePositives, TrueNegatives, Precision, Recall, AUC
import sklearn
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
dataset, dataset_info = tfds.load('malaria', with_info=True, as_supervised=True, split=['train'], shuffle_files=True)
# Out:
# Downloading and preparing dataset 337.08 MiB (download: 337.08 MiB, generated: Unknown size, total: 337.08 MiB) to /root/tensorflow_datasets/malaria/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Shuffling /root/tensorflow_datasets/malaria/1.0.0.incompleteN3RIFY/malaria-train.tfrecord*...:   0%|          …
# Dataset malaria downloaded and prepared to /root/tensorflow_datasets/malaria/1.0.0. Subsequent calls will reuse this data.

# %%
DATASET_SIZE = len(dataset[0])

# %%
TRAIN_RATIO = 0.6
VAL_RATIO = 0.2
TEST_RATIO = 0.2

def splits(dataset, TRAIN_RATIO, VAL_RATIO, TEST_RATIO):
  train_dataset = dataset.take(int(TRAIN_RATIO*DATASET_SIZE))

  val_test_dataset = dataset.skip(int(TRAIN_RATIO*DATASET_SIZE))
  val_dataset = val_test_dataset.take(int(VAL_RATIO*DATASET_SIZE))

  test_dataset = val_test_dataset.skip(int(VAL_RATIO*DATASET_SIZE))
  return train_dataset, val_dataset, test_dataset

train_dataset, val_dataset, test_dataset = splits(dataset[0], TRAIN_RATIO, VAL_RATIO, TEST_RATIO)

IM_SIZE = 224
def resize_rescale(image, label):
  return tf.image.resize(image, (IM_SIZE, IM_SIZE))/255.0, label

train_dataset = train_dataset.map(resize_rescale)
val_dataset = val_dataset.map(resize_rescale)
test_dataset = test_dataset.map(resize_rescale)

BATCH_SIZE = 32
train_dataset = train_dataset.shuffle(buffer_size=8, reshuffle_each_iteration=True).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
val_dataset = val_dataset.shuffle(buffer_size=8).batch(BATCH_SIZE)
# test_dataset = test_dataset.shuffle(buffer_size=8).batch(BATCH_SIZE)

# %%
model = tf.keras.Sequential([InputLayer(input_shape=(IM_SIZE, IM_SIZE, 3)),

                             Conv2D(filters=6, kernel_size=3, strides=1, padding='valid', activation='relu'),
                             BatchNormalization(),
                             MaxPool2D(pool_size=2, strides=2),

                             Conv2D(filters=16, kernel_size=3, strides=1, padding='valid', activation='relu'),
                             BatchNormalization(),
                             MaxPool2D(pool_size=2, strides=2),

                             Flatten(),

                             Dense(100, activation='sigmoid'),
                             BatchNormalization(),
                             Dense(10, activation='sigmoid'),
                             BatchNormalization(),
                             Dense(1, activation='sigmoid')]) # 0 or 1
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 6)       168
#
#  batch_normalization (BatchN  (None, 222, 222, 6)      24
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 6)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 16)      880
#
#  batch_normalization_1 (Batc  (None, 109, 109, 16)     64
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 16)       0
#  2D)
#
#  flatten (Flatten)           (None, 46656)             0
#
#  dense (Dense)               (None, 100)               4665700
#
#  batch_normalization_2 (Batc  (None, 100)              400
#  hNormalization)
#
#  dense_1 (Dense)             (None, 10)                1010
#
#  batch_normalization_3 (Batc  (None, 10)               40
#  hNormalization)
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 4,668,297
# Trainable params: 4,668,033
# Non-trainable params: 264
# _________________________________________________________________
# None

# %%
metrics = [BinaryAccuracy(name='accuracy'),
           Precision(name='precision'),
           Recall(name='recall'),
           AUC(name='auc')]
model.compile(optimizer=Adam(learning_rate=0.001),
              loss=BinaryCrossentropy(),
              metrics=metrics)
history = model.fit(train_dataset, validation_data=val_dataset, epochs=3, verbose=1)
# Out:
# Epoch 1/3
# 517/517 [==============================] - 55s 81ms/step - loss: 0.6582 - accuracy: 0.6287 - precision: 0.6218 - recall: 0.6553 - auc: 0.6682 - val_loss: 0.9256 - val_accuracy: 0.4983 - val_precision: 0.5000 - val_recall: 3.6166e-04 - val_auc: 0.5229
# Epoch 2/3
# 517/517 [==============================] - 44s 85ms/step - loss: 0.5137 - accuracy: 0.7477 - precision: 0.7262 - recall: 0.7945 - auc: 0.8264 - val_loss: 0.3474 - val_accuracy: 0.8732 - val_precision: 0.8162 - val_recall: 0.9642 - val_auc: 0.9309
# Epoch 3/3
# 517/517 [==============================] - 43s 83ms/step - loss: 0.3207 - accuracy: 0.8813 - precision: 0.8544 - recall: 0.9190 - auc: 0.9297 - val_loss: 0.2627 - val_accuracy: 0.9165 - val_precision: 0.8771 - val_recall: 0.9692 - val_auc: 0.9487

# %% [markdown]
# ## Callbacks
#
# Utilities called at certain points during model training.

# %% [markdown]
# https://www.tensorflow.org/api_docs/python/tf/keras/callbacks

# %%
from tensorflow.keras.callbacks import Callback, CSVLogger

# %%
class LossCallback(Callback):
  def on_epoch_end(self, epoch, logs):
    '''Print out the loss values at the end of the epoch'''
    loss = logs["loss"]
    print(f"\nEpoch Number {epoch+1} the model has a loss of {loss}")

  def on_batch_end(self, batch, logs):
    loss = logs["loss"]
    print(f"\nBatch Number {batch+1} the model has a loss of {loss}")

# %%
metrics = [BinaryAccuracy(name='accuracy'),
           Precision(name='precision'),
           Recall(name='recall'),
           AUC(name='auc')]
model.compile(optimizer=Adam(learning_rate=0.001),
              loss=BinaryCrossentropy(),
              metrics=metrics)
history = model.fit(train_dataset, validation_data=val_dataset, epochs=1, verbose=1, callbacks = [LossCallback()])
# Out:
# Batch Number 1 the model has a loss of 0.2658993601799011
#   1/517 [..............................] - ETA: 37:14 - loss: 0.2659 - accuracy: 0.9062 - precision: 0.8824 - recall: 0.9375 - auc: 0.9375
# Batch Number 2 the model has a loss of 0.24996784329414368
#
# Batch Number 3 the model has a loss of 0.29177364706993103
#   3/517 [..............................] - ETA: 23s - loss: 0.2918 - accuracy: 0.8854 - precision: 0.8235 - recall: 0.9545 - auc: 0.9417
# Batch Number 4 the model has a loss of 0.31359952688217163
#
# Batch Number 5 the model has a loss of 0.2864079475402832
#   5/517 [..............................] - ETA: 23s - loss: 0.2864 - accuracy: 0.9062 - precision: 0.8791 - recall: 0.9524 - auc: 0.9397
# Batch Number 6 the model has a loss of 0.2726671099662781
#
# Batch Number 7 the model has a loss of 0.2761997878551483
#   7/517 [..............................] - ETA: 22s - loss: 0.2762 - accuracy: 0.9152 - precision: 0.8992 - recall: 0.9508 - auc: 0.9427
# Batch Number 8 the model has a loss of 0.29149818420410156
#
# Batch Number 9 the model has a loss of 0.3302818834781647
#   9/517 [..............................] - ETA: 23s - loss: 0.3303 - accuracy: 0.8924 - precision: 0.8720 - recall: 0.9346 - auc: 0.9186
# Batch Number 10 the model has a loss of 0.34938254952430725
#
# Batch Number 11 the model has a loss of 0.3403342068195343
#  11/517 [..............................] - ETA: 23s - loss: 0.3403 - accuracy: 0.8949 - precision: 0.8788 - recall: 0.9305 - auc: 0.9149
# Batch Number 12 the model has a loss of 0.34058961272239685
#  12/517 [..............................] - ETA: 23s - loss: 0.3406 - accuracy: 0.8932 - precision: 0.8826 - recall: 0.9216 - auc: 0.9181
# Batch Number 13 the model has a loss of 0.36154085397720337
#  13/517 [..............................] - ETA: 24s - loss: 0.3615 - accuracy: 0.8846 - precision: 0.8745 - recall: 0.9140 - auc: 0.9103
# Batch Number 14 the model has a loss of 0.364543616771698
#
# Batch Number 15 the model has a loss of 0.35890617966651917
#  15/517 [..............................] - ETA: 23s - loss: 0.3589 - accuracy: 0.8875 - precision: 0.8835 - recall: 0.9109 - auc: 0.9133
# Batch Number 16 the model has a loss of 0.3549193739891052
#
# Batch Number 17 the model has a loss of 0.3568309247493744
#  17/517 [..............................] - ETA: 23s - loss: 0.3568 - accuracy: 0.8824 - precision: 0.8682 - recall: 0.9113 - auc: 0.9152
# Batch Number 18 the model has a loss of 0.3673827350139618
#
# Batch Number 19 the model has a loss of 0.36456575989723206
#  19/517 [>.............................] - ETA: 23s - loss: 0.3646 - accuracy: 0.8799 - precision: 0.8646 - recall: 0.9065 - auc: 0.9126
# Batch Number 20 the model has a loss of 0.36195215582847595
#  20/517 [>.............................] - ETA: 23s - loss: 0.3620 - accuracy: 0.8781 - precision: 0.8596 - recall: 0.9074 - auc: 0.9138
# Batch Number 21 the model has a loss of 0.3553287088871002
#
# Batch Number 22 the model has a loss of 0.3579603433609009
#  22/517 [>.............................] - ETA: 23s - loss: 0.3580 - accuracy: 0.8807 - precision: 0.8667 - recall: 0.9053 - auc: 0.9151
# Batch Number 23 the model has a loss of 0.3530254065990448
#
# Batch Number 24 the model has a loss of 0.35600265860557556
#  24/517 [>.............................] - ETA: 22s - loss: 0.3560 - accuracy: 0.8841 - precision: 0.8747 - recall: 0.9036 - auc: 0.9162
# Batch Number 25 the model has a loss of 0.35612067580223083
#
# Batch Number 26 the model has a loss of 0.3560650050640106
#  26/517 [>.............................] - ETA: 22s - loss: 0.3561 - accuracy: 0.8786 - precision: 0.8650 - recall: 0.9000 - auc: 0.9177
# Batch Number 27 the model has a loss of 0.34876343607902527
#
# Batch Number 28 the model has a loss of 0.34274742007255554
#  28/517 [>.............................] - ETA: 22s - loss: 0.3427 - accuracy: 0.8839 - precision: 0.8721 - recall: 0.9029 - auc: 0.9231
# Batch Number 29 the model has a loss of 0.34097668528556824
#
# Batch Number 30 the model has a loss of 0.33730003237724304
#  30/517 [>.............................] - ETA: 22s - loss: 0.3373 - accuracy: 0.8854 - precision: 0.8750 - recall: 0.9037 - auc: 0.9256
# Batch Number 31 the model has a loss of 0.3395000994205475
#  31/517 [>.............................] - ETA: 22s - loss: 0.3395 - accuracy: 0.8861 - precision: 0.8774 - recall: 0.9034 - auc: 0.9247
# Batch Number 32 the model has a loss of 0.33689770102500916
#
# Batch Number 33 the model has a loss of 0.33660316467285156
#  33/517 [>.............................] - ETA: 22s - loss: 0.3366 - accuracy: 0.8864 - precision: 0.8759 - recall: 0.9052 - auc: 0.9254
# Batch Number 34 the model has a loss of 0.3340330123901367
#
# Batch Number 35 the model has a loss of 0.3325348496437073
#  35/517 [=>............................] - ETA: 22s - loss: 0.3325 - accuracy: 0.8866 - precision: 0.8786 - recall: 0.9045 - auc: 0.9276
# Batch Number 36 the model has a loss of 0.33266058564186096
#  36/517 [=>............................] - ETA: 22s - loss: 0.3327 - accuracy: 0.8863 - precision: 0.8789 - recall: 0.9040 - auc: 0.9277
# Batch Number 37 the model has a loss of 0.33222901821136475
#  37/517 [=>............................] - ETA: 22s - loss: 0.3322 - accuracy: 0.8877 - precision: 0.8831 - recall: 0.9045 - auc: 0.9278
# Batch Number 38 the model has a loss of 0.3262350857257843
#  38/517 [=>............................] - ETA: 22s - loss: 0.3262 - accuracy: 0.8906 - precision: 0.8863 - recall: 0.9072 - auc: 0.9302
# Batch Number 39 the model has a loss of 0.33040791749954224
#  39/517 [=>............................] - ETA: 22s - loss: 0.3304 - accuracy: 0.8878 - precision: 0.8832 - recall: 0.9049 - auc: 0.9288
# Batch Number 40 the model has a loss of 0.32969874143600464
#
# Batch Number 41 the model has a loss of 0.32548782229423523
#  41/517 [=>............................] - ETA: 22s - loss: 0.3255 - accuracy: 0.8902 - precision: 0.8886 - recall: 0.9041 - auc: 0.9310
# Batch Number 42 the model has a loss of 0.3216480016708374
#
# Batch Number 43 the model has a loss of 0.3187086582183838
#  43/517 [=>............................] - ETA: 22s - loss: 0.3187 - accuracy: 0.8932 - precision: 0.8924 - recall: 0.9059 - auc: 0.9339
# Batch Number 44 the model has a loss of 0.32070234417915344
#
# Batch Number 45 the model has a loss of 0.32121530175209045
#  45/517 [=>............................] - ETA: 22s - loss: 0.3212 - accuracy: 0.8917 - precision: 0.8896 - recall: 0.9061 - auc: 0.9333
# Batch Number 46 the model has a loss of 0.317913293838501
#
# Batch Number 47 the model has a loss of 0.3156517446041107
#  47/517 [=>............................] - ETA: 22s - loss: 0.3157 - accuracy: 0.8936 - precision: 0.8904 - recall: 0.9085 - auc: 0.9350
# Batch Number 48 the model has a loss of 0.3152770698070526
#
# Batch Number 49 the model has a loss of 0.31268954277038574
#  49/517 [=>............................] - ETA: 22s - loss: 0.3127 - accuracy: 0.8948 - precision: 0.8890 - recall: 0.9119 - auc: 0.9357
# Batch Number 50 the model has a loss of 0.31001150608062744
#
# Batch Number 51 the model has a loss of 0.3090374171733856
#  51/517 [=>............................] - ETA: 21s - loss: 0.3090 - accuracy: 0.8958 - precision: 0.8923 - recall: 0.9111 - auc: 0.9370
# Batch Number 52 the model has a loss of 0.3074477016925812
#  52/517 [==>...........................] - ETA: 21s - loss: 0.3074 - accuracy: 0.8966 - precision: 0.8934 - recall: 0.9118 - auc: 0.9375
# Batch Number 53 the model has a loss of 0.304004967212677
#
# Batch Number 54 the model has a loss of 0.30153200030326843
#  54/517 [==>...........................] - ETA: 21s - loss: 0.3015 - accuracy: 0.8987 - precision: 0.8948 - recall: 0.9136 - auc: 0.9399
# Batch Number 55 the model has a loss of 0.29942137002944946
#
# Batch Number 56 the model has a loss of 0.2978840470314026
#  56/517 [==>...........................] - ETA: 21s - loss: 0.2979 - accuracy: 0.9007 - precision: 0.8974 - recall: 0.9146 - auc: 0.9415
# Batch Number 57 the model has a loss of 0.2974880039691925
#  57/517 [==>...........................] - ETA: 21s - loss: 0.2975 - accuracy: 0.9008 - precision: 0.8961 - recall: 0.9159 - auc: 0.9415
# Batch Number 58 the model has a loss of 0.30086952447891235
#
# Batch Number 59 the model has a loss of 0.30101466178894043
#  59/517 [==>...........................] - ETA: 21s - loss: 0.3010 - accuracy: 0.8994 - precision: 0.8912 - recall: 0.9168 - auc: 0.9396
# Batch Number 60 the model has a loss of 0.2985718548297882
#
# Batch Number 61 the model has a loss of 0.29928702116012573
#  61/517 [==>...........................] - ETA: 21s - loss: 0.2993 - accuracy: 0.8996 - precision: 0.8924 - recall: 0.9171 - auc: 0.9405
# Batch Number 62 the model has a loss of 0.3014369308948517
#
# Batch Number 63 the model has a loss of 0.3032572269439697
#  63/517 [==>...........................] - ETA: 21s - loss: 0.3033 - accuracy: 0.8973 - precision: 0.8882 - recall: 0.9163 - auc: 0.9385
# Batch Number 64 the model has a loss of 0.30270740389823914
#
# Batch Number 65 the model has a loss of 0.2994687557220459
#  65/517 [==>...........................] - ETA: 21s - loss: 0.2995 - accuracy: 0.8990 - precision: 0.8908 - recall: 0.9173 - auc: 0.9398
# Batch Number 66 the model has a loss of 0.29841095209121704
#
# Batch Number 67 the model has a loss of 0.2991009056568146
#  67/517 [==>...........................] - ETA: 20s - loss: 0.2991 - accuracy: 0.8988 - precision: 0.8908 - recall: 0.9173 - auc: 0.9404
# Batch Number 68 the model has a loss of 0.29725345969200134
#
# Batch Number 69 the model has a loss of 0.2968633770942688
#  69/517 [===>..........................] - ETA: 20s - loss: 0.2969 - accuracy: 0.8999 - precision: 0.8930 - recall: 0.9172 - auc: 0.9413
# Batch Number 70 the model has a loss of 0.29613855481147766
#
# Batch Number 71 the model has a loss of 0.29574236273765564
#  71/517 [===>..........................] - ETA: 20s - loss: 0.2957 - accuracy: 0.8996 - precision: 0.8929 - recall: 0.9171 - auc: 0.9417
# Batch Number 72 the model has a loss of 0.2939760088920593
#
# Batch Number 73 the model has a loss of 0.29415005445480347
#  73/517 [===>..........................] - ETA: 20s - loss: 0.2942 - accuracy: 0.8994 - precision: 0.8927 - recall: 0.9169 - auc: 0.9427
# Batch Number 74 the model has a loss of 0.2931668758392334
#  74/517 [===>..........................] - ETA: 20s - loss: 0.2932 - accuracy: 0.8999 - precision: 0.8932 - recall: 0.9171 - auc: 0.9432
# Batch Number 75 the model has a loss of 0.2927778661251068
#  75/517 [===>..........................] - ETA: 20s - loss: 0.2928 - accuracy: 0.8996 - precision: 0.8930 - recall: 0.9166 - auc: 0.9436
# Batch Number 76 the model has a loss of 0.29140403866767883
#
# Batch Number 77 the model has a loss of 0.2923927903175354
#  77/517 [===>..........................] - ETA: 20s - loss: 0.2924 - accuracy: 0.8989 - precision: 0.8933 - recall: 0.9149 - auc: 0.9437
# Batch Number 78 the model has a loss of 0.2913145124912262
#  78/517 [===>..........................] - ETA: 20s - loss: 0.2913 - accuracy: 0.8994 - precision: 0.8938 - recall: 0.9152 - auc: 0.9442
# Batch Number 79 the model has a loss of 0.29029789566993713
#
# Batch Number 80 the model has a loss of 0.2900795638561249
#  80/517 [===>..........................] - ETA: 20s - loss: 0.2901 - accuracy: 0.9000 - precision: 0.8949 - recall: 0.9151 - auc: 0.9447
# Batch Number 81 the model has a loss of 0.2897503674030304
#  81/517 [===>..........................] - ETA: 20s - loss: 0.2898 - accuracy: 0.9005 - precision: 0.8962 - recall: 0.9148 - auc: 0.9449
# Batch Number 82 the model has a loss of 0.2916053831577301
#
# Batch Number 83 the model has a loss of 0.29111093282699585
#  83/517 [===>..........................] - ETA: 20s - loss: 0.2911 - accuracy: 0.8998 - precision: 0.8940 - recall: 0.9160 - auc: 0.9437
# Batch Number 84 the model has a loss of 0.2906704843044281
#  84/517 [===>..........................] - ETA: 20s - loss: 0.2907 - accuracy: 0.9003 - precision: 0.8947 - recall: 0.9164 - auc: 0.9436
# Batch Number 85 the model has a loss of 0.2921217381954193
#  85/517 [===>..........................] - ETA: 20s - loss: 0.2921 - accuracy: 0.8993 - precision: 0.8917 - recall: 0.9170 - auc: 0.9430
# Batch Number 86 the model has a loss of 0.2912817597389221
#
# Batch Number 87 the model has a loss of 0.29208576679229736
#  87/517 [====>.........................] - ETA: 20s - loss: 0.2921 - accuracy: 0.8994 - precision: 0.8918 - recall: 0.9177 - auc: 0.9428
# Batch Number 88 the model has a loss of 0.29179394245147705
#  88/517 [====>.........................] - ETA: 20s - loss: 0.2918 - accuracy: 0.8995 - precision: 0.8916 - recall: 0.9178 - auc: 0.9428
# Batch Number 89 the model has a loss of 0.29320964217185974
#  89/517 [====>.........................] - ETA: 20s - loss: 0.2932 - accuracy: 0.8985 - precision: 0.8895 - recall: 0.9179 - auc: 0.9422
# Batch Number 90 the model has a loss of 0.29349929094314575
#
# Batch Number 91 the model has a loss of 0.29400116205215454
#  91/517 [====>.........................] - ETA: 20s - loss: 0.2940 - accuracy: 0.8970 - precision: 0.8860 - recall: 0.9179 - auc: 0.9421
# Batch Number 92 the model has a loss of 0.29424819350242615
#
# Batch Number 93 the model has a loss of 0.2936652600765228
#  93/517 [====>.........................] - ETA: 19s - loss: 0.2937 - accuracy: 0.8972 - precision: 0.8859 - recall: 0.9184 - auc: 0.9421
# Batch Number 94 the model has a loss of 0.2947785258293152
#
# Batch Number 95 the model has a loss of 0.2941802740097046
#  95/517 [====>.........................] - ETA: 19s - loss: 0.2942 - accuracy: 0.8967 - precision: 0.8855 - recall: 0.9183 - auc: 0.9417
# Batch Number 96 the model has a loss of 0.29477110505104065
#  96/517 [====>.........................] - ETA: 19s - loss: 0.2948 - accuracy: 0.8962 - precision: 0.8836 - recall: 0.9189 - auc: 0.9414
# Batch Number 97 the model has a loss of 0.2954084575176239
#
# Batch Number 98 the model has a loss of 0.2944154739379883
#  98/517 [====>.........................] - ETA: 19s - loss: 0.2944 - accuracy: 0.8970 - precision: 0.8832 - recall: 0.9201 - auc: 0.9411
# Batch Number 99 the model has a loss of 0.2936347424983978
#  99/517 [====>.........................] - ETA: 19s - loss: 0.2936 - accuracy: 0.8971 - precision: 0.8839 - recall: 0.9199 - auc: 0.9414
# Batch Number 100 the model has a loss of 0.29190367460250854
#
# Batch Number 101 the model has a loss of 0.29022836685180664
# 101/517 [====>.........................] - ETA: 19s - loss: 0.2902 - accuracy: 0.8985 - precision: 0.8853 - recall: 0.9207 - auc: 0.9428
# Batch Number 102 the model has a loss of 0.2897084653377533
#
# Batch Number 103 the model has a loss of 0.2906988263130188
# 103/517 [====>.........................] - ETA: 19s - loss: 0.2907 - accuracy: 0.8981 - precision: 0.8840 - recall: 0.9208 - auc: 0.9427
# Batch Number 104 the model has a loss of 0.2922143042087555
#
# Batch Number 105 the model has a loss of 0.29216158390045166
# 105/517 [=====>........................] - ETA: 19s - loss: 0.2922 - accuracy: 0.8979 - precision: 0.8827 - recall: 0.9215 - auc: 0.9418
# Batch Number 106 the model has a loss of 0.2917422652244568
# 106/517 [=====>........................] - ETA: 19s - loss: 0.2917 - accuracy: 0.8983 - precision: 0.8834 - recall: 0.9218 - auc: 0.9417
# Batch Number 107 the model has a loss of 0.29079416394233704
#
# Batch Number 108 the model has a loss of 0.28932154178619385
# 108/517 [=====>........................] - ETA: 19s - loss: 0.2893 - accuracy: 0.8996 - precision: 0.8845 - recall: 0.9232 - auc: 0.9426
# Batch Number 109 the model has a loss of 0.2874108850955963
#
# Batch Number 110 the model has a loss of 0.28650403022766113
# 110/517 [=====>........................] - ETA: 19s - loss: 0.2865 - accuracy: 0.9006 - precision: 0.8859 - recall: 0.9235 - auc: 0.9439
# Batch Number 111 the model has a loss of 0.2870447635650635
#
# Batch Number 112 the model has a loss of 0.28702589869499207
# 112/517 [=====>........................] - ETA: 19s - loss: 0.2870 - accuracy: 0.9001 - precision: 0.8851 - recall: 0.9230 - auc: 0.9434
# Batch Number 113 the model has a loss of 0.28602805733680725
# 113/517 [=====>........................] - ETA: 18s - loss: 0.2860 - accuracy: 0.9007 - precision: 0.8854 - recall: 0.9236 - auc: 0.9437
# Batch Number 114 the model has a loss of 0.2845836579799652
#
# Batch Number 115 the model has a loss of 0.2826807498931885
# 115/517 [=====>........................] - ETA: 18s - loss: 0.2827 - accuracy: 0.9022 - precision: 0.8875 - recall: 0.9246 - auc: 0.9449
# Batch Number 116 the model has a loss of 0.2846048176288605
# 116/517 [=====>........................] - ETA: 18s - loss: 0.2846 - accuracy: 0.9011 - precision: 0.8855 - recall: 0.9245 - auc: 0.9442
# Batch Number 117 the model has a loss of 0.284129798412323
# 117/517 [=====>........................] - ETA: 18s - loss: 0.2841 - accuracy: 0.9012 - precision: 0.8864 - recall: 0.9237 - auc: 0.9445
# Batch Number 118 the model has a loss of 0.28385651111602783
# 118/517 [=====>........................] - ETA: 18s - loss: 0.2839 - accuracy: 0.9015 - precision: 0.8869 - recall: 0.9239 - auc: 0.9444
# Batch Number 119 the model has a loss of 0.28425294160842896
#
# Batch Number 120 the model has a loss of 0.2850785255432129
# 120/517 [=====>........................] - ETA: 18s - loss: 0.2851 - accuracy: 0.9005 - precision: 0.8842 - recall: 0.9243 - auc: 0.9440
# Batch Number 121 the model has a loss of 0.2844463288784027
# 121/517 [======>.......................] - ETA: 18s - loss: 0.2844 - accuracy: 0.9008 - precision: 0.8848 - recall: 0.9245 - auc: 0.9443
# Batch Number 122 the model has a loss of 0.2856767475605011
#
# Batch Number 123 the model has a loss of 0.28476715087890625
# 123/517 [======>.......................] - ETA: 18s - loss: 0.2848 - accuracy: 0.9009 - precision: 0.8848 - recall: 0.9240 - auc: 0.9440
# Batch Number 124 the model has a loss of 0.2840723395347595
# 124/517 [======>.......................] - ETA: 18s - loss: 0.2841 - accuracy: 0.9012 - precision: 0.8847 - recall: 0.9245 - auc: 0.9443
# Batch Number 125 the model has a loss of 0.28291627764701843
#
# Batch Number 126 the model has a loss of 0.28201740980148315
# 126/517 [======>.......................] - ETA: 18s - loss: 0.2820 - accuracy: 0.9020 - precision: 0.8851 - recall: 0.9256 - auc: 0.9449
# Batch Number 127 the model has a loss of 0.2813411056995392
# 127/517 [======>.......................] - ETA: 18s - loss: 0.2813 - accuracy: 0.9023 - precision: 0.8855 - recall: 0.9257 - auc: 0.9451
# Batch Number 128 the model has a loss of 0.2810325026512146
#
# Batch Number 129 the model has a loss of 0.28082919120788574
# 129/517 [======>.......................] - ETA: 18s - loss: 0.2808 - accuracy: 0.9026 - precision: 0.8862 - recall: 0.9254 - auc: 0.9452
# Batch Number 130 the model has a loss of 0.2798886001110077
#
# Batch Number 131 the model has a loss of 0.28050151467323303
# 131/517 [======>.......................] - ETA: 18s - loss: 0.2805 - accuracy: 0.9027 - precision: 0.8855 - recall: 0.9259 - auc: 0.9454
# Batch Number 132 the model has a loss of 0.2788451611995697
#
# Batch Number 133 the model has a loss of 0.27748042345046997
# 133/517 [======>.......................] - ETA: 18s - loss: 0.2775 - accuracy: 0.9039 - precision: 0.8870 - recall: 0.9265 - auc: 0.9466
# Batch Number 134 the model has a loss of 0.2768855094909668
#
# Batch Number 135 the model has a loss of 0.2753087282180786
# 135/517 [======>.......................] - ETA: 17s - loss: 0.2753 - accuracy: 0.9049 - precision: 0.8884 - recall: 0.9273 - auc: 0.9474
# Batch Number 136 the model has a loss of 0.2745615839958191
# 136/517 [======>.......................] - ETA: 17s - loss: 0.2746 - accuracy: 0.9051 - precision: 0.8888 - recall: 0.9274 - auc: 0.9477
# Batch Number 137 the model has a loss of 0.2738424837589264
#
# Batch Number 138 the model has a loss of 0.27357858419418335
# 138/517 [=======>......................] - ETA: 17s - loss: 0.2736 - accuracy: 0.9058 - precision: 0.8904 - recall: 0.9272 - auc: 0.9481
# Batch Number 139 the model has a loss of 0.273301362991333
# 139/517 [=======>......................] - ETA: 17s - loss: 0.2733 - accuracy: 0.9060 - precision: 0.8909 - recall: 0.9274 - auc: 0.9480
# Batch Number 140 the model has a loss of 0.2731056809425354
# 140/517 [=======>......................] - ETA: 17s - loss: 0.2731 - accuracy: 0.9062 - precision: 0.8907 - recall: 0.9278 - auc: 0.9480
# Batch Number 141 the model has a loss of 0.27204665541648865
#
# Batch Number 142 the model has a loss of 0.2704510986804962
# 142/517 [=======>......................] - ETA: 17s - loss: 0.2705 - accuracy: 0.9074 - precision: 0.8917 - recall: 0.9287 - auc: 0.9490
# Batch Number 143 the model has a loss of 0.27045467495918274
#
# Batch Number 144 the model has a loss of 0.2696172893047333
# 144/517 [=======>......................] - ETA: 17s - loss: 0.2696 - accuracy: 0.9076 - precision: 0.8917 - recall: 0.9293 - auc: 0.9494
# Batch Number 145 the model has a loss of 0.2689441442489624
#
# Batch Number 146 the model has a loss of 0.2683661878108978
# 146/517 [=======>......................] - ETA: 17s - loss: 0.2684 - accuracy: 0.9077 - precision: 0.8912 - recall: 0.9303 - auc: 0.9500
# Batch Number 147 the model has a loss of 0.2691258192062378
#
# Batch Number 148 the model has a loss of 0.26833170652389526
# 148/517 [=======>......................] - ETA: 17s - loss: 0.2683 - accuracy: 0.9075 - precision: 0.8912 - recall: 0.9300 - auc: 0.9501
# Batch Number 149 the model has a loss of 0.266979843378067
#
# Batch Number 150 the model has a loss of 0.26596343517303467
# 150/517 [=======>......................] - ETA: 17s - loss: 0.2660 - accuracy: 0.9085 - precision: 0.8923 - recall: 0.9310 - auc: 0.9509
# Batch Number 151 the model has a loss of 0.2650686204433441
# 151/517 [=======>......................] - ETA: 17s - loss: 0.2651 - accuracy: 0.9091 - precision: 0.8931 - recall: 0.9316 - auc: 0.9512
# Batch Number 152 the model has a loss of 0.2637493312358856
# 152/517 [=======>......................] - ETA: 17s - loss: 0.2637 - accuracy: 0.9097 - precision: 0.8938 - recall: 0.9320 - auc: 0.9516
# Batch Number 153 the model has a loss of 0.2624881863594055
#
# Batch Number 154 the model has a loss of 0.2621181905269623
# 154/517 [=======>......................] - ETA: 16s - loss: 0.2621 - accuracy: 0.9103 - precision: 0.8940 - recall: 0.9329 - auc: 0.9522
# Batch Number 155 the model has a loss of 0.26189395785331726
#
# Batch Number 156 the model has a loss of 0.2611611783504486
# 156/517 [========>.....................] - ETA: 16s - loss: 0.2612 - accuracy: 0.9109 - precision: 0.8942 - recall: 0.9337 - auc: 0.9524
# Batch Number 157 the model has a loss of 0.26025480031967163
#
# Batch Number 158 the model has a loss of 0.26046669483184814
# 158/517 [========>.....................] - ETA: 16s - loss: 0.2605 - accuracy: 0.9108 - precision: 0.8933 - recall: 0.9344 - auc: 0.9527
# Batch Number 159 the model has a loss of 0.2601448595523834
# 159/517 [========>.....................] - ETA: 16s - loss: 0.2601 - accuracy: 0.9110 - precision: 0.8936 - recall: 0.9344 - auc: 0.9528
# Batch Number 160 the model has a loss of 0.25922372937202454
# 160/517 [========>.....................] - ETA: 16s - loss: 0.2592 - accuracy: 0.9113 - precision: 0.8943 - recall: 0.9345 - auc: 0.9531
# Batch Number 161 the model has a loss of 0.258256733417511
# 161/517 [========>.....................] - ETA: 16s - loss: 0.2583 - accuracy: 0.9117 - precision: 0.8945 - recall: 0.9349 - auc: 0.9535
# Batch Number 162 the model has a loss of 0.2577735185623169
# 162/517 [========>.....................] - ETA: 16s - loss: 0.2578 - accuracy: 0.9118 - precision: 0.8945 - recall: 0.9353 - auc: 0.9537
# Batch Number 163 the model has a loss of 0.2571263015270233
# 163/517 [========>.....................] - ETA: 16s - loss: 0.2571 - accuracy: 0.9118 - precision: 0.8945 - recall: 0.9353 - auc: 0.9540
# Batch Number 164 the model has a loss of 0.25985172390937805
# 164/517 [========>.....................] - ETA: 16s - loss: 0.2599 - accuracy: 0.9108 - precision: 0.8945 - recall: 0.9336 - auc: 0.9531
# Batch Number 165 the model has a loss of 0.25942790508270264
# 165/517 [========>.....................] - ETA: 17s - loss: 0.2594 - accuracy: 0.9112 - precision: 0.8946 - recall: 0.9339 - auc: 0.9532
# Batch Number 166 the model has a loss of 0.25943318009376526
# 166/517 [========>.....................] - ETA: 17s - loss: 0.2594 - accuracy: 0.9110 - precision: 0.8938 - recall: 0.9342 - auc: 0.9532
# Batch Number 167 the model has a loss of 0.25826871395111084
# 167/517 [========>.....................] - ETA: 17s - loss: 0.2583 - accuracy: 0.9115 - precision: 0.8942 - recall: 0.9345 - auc: 0.9537
# Batch Number 168 the model has a loss of 0.2590324878692627
# 168/517 [========>.....................] - ETA: 17s - loss: 0.2590 - accuracy: 0.9113 - precision: 0.8945 - recall: 0.9339 - auc: 0.9535
# Batch Number 169 the model has a loss of 0.25891727209091187
# 169/517 [========>.....................] - ETA: 17s - loss: 0.2589 - accuracy: 0.9114 - precision: 0.8948 - recall: 0.9339 - auc: 0.9535
# Batch Number 170 the model has a loss of 0.25891032814979553
# 170/517 [========>.....................] - ETA: 17s - loss: 0.2589 - accuracy: 0.9116 - precision: 0.8951 - recall: 0.9340 - auc: 0.9535
# Batch Number 171 the model has a loss of 0.25851505994796753
# 171/517 [========>.....................] - ETA: 17s - loss: 0.2585 - accuracy: 0.9117 - precision: 0.8951 - recall: 0.9344 - auc: 0.9535
# Batch Number 172 the model has a loss of 0.25757837295532227
# 172/517 [========>.....................] - ETA: 17s - loss: 0.2576 - accuracy: 0.9121 - precision: 0.8958 - recall: 0.9345 - auc: 0.9539
# Batch Number 173 the model has a loss of 0.2580587863922119
# 173/517 [=========>....................] - ETA: 17s - loss: 0.2581 - accuracy: 0.9122 - precision: 0.8954 - recall: 0.9346 - auc: 0.9538
# Batch Number 174 the model has a loss of 0.2583062946796417
# 174/517 [=========>....................] - ETA: 17s - loss: 0.2583 - accuracy: 0.9120 - precision: 0.8956 - recall: 0.9340 - auc: 0.9537
# Batch Number 175 the model has a loss of 0.257448673248291
# 175/517 [=========>....................] - ETA: 17s - loss: 0.2574 - accuracy: 0.9121 - precision: 0.8956 - recall: 0.9344 - auc: 0.9540
# Batch Number 176 the model has a loss of 0.25817281007766724
# 176/517 [=========>....................] - ETA: 18s - loss: 0.2582 - accuracy: 0.9119 - precision: 0.8952 - recall: 0.9343 - auc: 0.9538
# Batch Number 177 the model has a loss of 0.2584707736968994
# 177/517 [=========>....................] - ETA: 18s - loss: 0.2585 - accuracy: 0.9117 - precision: 0.8944 - recall: 0.9346 - auc: 0.9536
# Batch Number 178 the model has a loss of 0.25752630829811096
# 178/517 [=========>....................] - ETA: 18s - loss: 0.2575 - accuracy: 0.9122 - precision: 0.8949 - recall: 0.9350 - auc: 0.9539
# Batch Number 179 the model has a loss of 0.2567184865474701
# 179/517 [=========>....................] - ETA: 18s - loss: 0.2567 - accuracy: 0.9125 - precision: 0.8952 - recall: 0.9354 - auc: 0.9542
# Batch Number 180 the model has a loss of 0.256475567817688
# 180/517 [=========>....................] - ETA: 18s - loss: 0.2565 - accuracy: 0.9127 - precision: 0.8953 - recall: 0.9358 - auc: 0.9543
# Batch Number 181 the model has a loss of 0.2565222382545471
# 181/517 [=========>....................] - ETA: 18s - loss: 0.2565 - accuracy: 0.9126 - precision: 0.8949 - recall: 0.9361 - auc: 0.9542
# Batch Number 182 the model has a loss of 0.2558629512786865
# 182/517 [=========>....................] - ETA: 18s - loss: 0.2559 - accuracy: 0.9129 - precision: 0.8952 - recall: 0.9365 - auc: 0.9544
# Batch Number 183 the model has a loss of 0.2553320825099945
# 183/517 [=========>....................] - ETA: 18s - loss: 0.2553 - accuracy: 0.9133 - precision: 0.8955 - recall: 0.9368 - auc: 0.9545
# Batch Number 184 the model has a loss of 0.25463834404945374
# 184/517 [=========>....................] - ETA: 18s - loss: 0.2546 - accuracy: 0.9136 - precision: 0.8957 - recall: 0.9371 - auc: 0.9547
# Batch Number 185 the model has a loss of 0.2545071542263031
# 185/517 [=========>....................] - ETA: 18s - loss: 0.2545 - accuracy: 0.9135 - precision: 0.8952 - recall: 0.9374 - auc: 0.9547
# Batch Number 186 the model has a loss of 0.25508755445480347
# 186/517 [=========>....................] - ETA: 18s - loss: 0.2551 - accuracy: 0.9135 - precision: 0.8952 - recall: 0.9374 - auc: 0.9545
# Batch Number 187 the model has a loss of 0.25400662422180176
# 187/517 [=========>....................] - ETA: 18s - loss: 0.2540 - accuracy: 0.9139 - precision: 0.8957 - recall: 0.9377 - auc: 0.9549
# Batch Number 188 the model has a loss of 0.25381752848625183
# 188/517 [=========>....................] - ETA: 18s - loss: 0.2538 - accuracy: 0.9139 - precision: 0.8960 - recall: 0.9375 - auc: 0.9549
# Batch Number 189 the model has a loss of 0.253445565700531
# 189/517 [=========>....................] - ETA: 18s - loss: 0.2534 - accuracy: 0.9140 - precision: 0.8963 - recall: 0.9375 - auc: 0.9550
# Batch Number 190 the model has a loss of 0.2528548240661621
# 190/517 [==========>...................] - ETA: 18s - loss: 0.2529 - accuracy: 0.9141 - precision: 0.8969 - recall: 0.9373 - auc: 0.9552
# Batch Number 191 the model has a loss of 0.2525458037853241
# 191/517 [==========>...................] - ETA: 18s - loss: 0.2525 - accuracy: 0.9143 - precision: 0.8971 - recall: 0.9373 - auc: 0.9552
# Batch Number 192 the model has a loss of 0.253445029258728
# 192/517 [==========>...................] - ETA: 17s - loss: 0.2534 - accuracy: 0.9141 - precision: 0.8973 - recall: 0.9367 - auc: 0.9549
# Batch Number 193 the model has a loss of 0.25310981273651123
# 193/517 [==========>...................] - ETA: 17s - loss: 0.2531 - accuracy: 0.9142 - precision: 0.8973 - recall: 0.9370 - auc: 0.9549
# Batch Number 194 the model has a loss of 0.25240468978881836
#
# Batch Number 195 the model has a loss of 0.25187748670578003
# 195/517 [==========>...................] - ETA: 17s - loss: 0.2519 - accuracy: 0.9147 - precision: 0.8977 - recall: 0.9377 - auc: 0.9553
# Batch Number 196 the model has a loss of 0.25212183594703674
# 196/517 [==========>...................] - ETA: 17s - loss: 0.2521 - accuracy: 0.9145 - precision: 0.8979 - recall: 0.9371 - auc: 0.9553
# Batch Number 197 the model has a loss of 0.25191250443458557
# 197/517 [==========>...................] - ETA: 17s - loss: 0.2519 - accuracy: 0.9147 - precision: 0.8981 - recall: 0.9371 - auc: 0.9554
# Batch Number 198 the model has a loss of 0.25216880440711975
# 198/517 [==========>...................] - ETA: 17s - loss: 0.2522 - accuracy: 0.9145 - precision: 0.8978 - recall: 0.9371 - auc: 0.9553
# Batch Number 199 the model has a loss of 0.2516135275363922
# 199/517 [==========>...................] - ETA: 17s - loss: 0.2516 - accuracy: 0.9146 - precision: 0.8978 - recall: 0.9375 - auc: 0.9555
# Batch Number 200 the model has a loss of 0.2517201900482178
# 200/517 [==========>...................] - ETA: 17s - loss: 0.2517 - accuracy: 0.9145 - precision: 0.8976 - recall: 0.9374 - auc: 0.9555
# Batch Number 201 the model has a loss of 0.2507510483264923
# 201/517 [==========>...................] - ETA: 17s - loss: 0.2508 - accuracy: 0.9150 - precision: 0.8981 - recall: 0.9377 - auc: 0.9558
# Batch Number 202 the model has a loss of 0.25002533197402954
# 202/517 [==========>...................] - ETA: 17s - loss: 0.2500 - accuracy: 0.9152 - precision: 0.8987 - recall: 0.9378 - auc: 0.9560
# Batch Number 203 the model has a loss of 0.2494504451751709
#
# Batch Number 204 the model has a loss of 0.24850979447364807
# 204/517 [==========>...................] - ETA: 17s - loss: 0.2485 - accuracy: 0.9157 - precision: 0.8992 - recall: 0.9384 - auc: 0.9565
# Batch Number 205 the model has a loss of 0.24790626764297485
# 205/517 [==========>...................] - ETA: 17s - loss: 0.2479 - accuracy: 0.9160 - precision: 0.8997 - recall: 0.9385 - auc: 0.9568
# Batch Number 206 the model has a loss of 0.24734677374362946
#
# Batch Number 207 the model has a loss of 0.24781963229179382
# 207/517 [===========>..................] - ETA: 17s - loss: 0.2478 - accuracy: 0.9161 - precision: 0.8991 - recall: 0.9390 - auc: 0.9568
# Batch Number 208 the model has a loss of 0.24873565137386322
#
# Batch Number 209 the model has a loss of 0.24870936572551727
# 209/517 [===========>..................] - ETA: 17s - loss: 0.2487 - accuracy: 0.9152 - precision: 0.8973 - recall: 0.9391 - auc: 0.9565
# Batch Number 210 the model has a loss of 0.24838921427726746
# 210/517 [===========>..................] - ETA: 17s - loss: 0.2484 - accuracy: 0.9153 - precision: 0.8975 - recall: 0.9391 - auc: 0.9567
# Batch Number 211 the model has a loss of 0.2489398866891861
#
# Batch Number 212 the model has a loss of 0.2491176724433899
# 212/517 [===========>..................] - ETA: 16s - loss: 0.2491 - accuracy: 0.9148 - precision: 0.8967 - recall: 0.9387 - auc: 0.9566
# Batch Number 213 the model has a loss of 0.24922755360603333
# 213/517 [===========>..................] - ETA: 16s - loss: 0.2492 - accuracy: 0.9148 - precision: 0.8966 - recall: 0.9387 - auc: 0.9566
# Batch Number 214 the model has a loss of 0.24975046515464783
# 214/517 [===========>..................] - ETA: 16s - loss: 0.2498 - accuracy: 0.9146 - precision: 0.8961 - recall: 0.9386 - auc: 0.9564
# Batch Number 215 the model has a loss of 0.24916142225265503
#
# Batch Number 216 the model has a loss of 0.2493770569562912
# 216/517 [===========>..................] - ETA: 16s - loss: 0.2494 - accuracy: 0.9146 - precision: 0.8962 - recall: 0.9386 - auc: 0.9565
# Batch Number 217 the model has a loss of 0.24890081584453583
#
# Batch Number 218 the model has a loss of 0.2482461780309677
# 218/517 [===========>..................] - ETA: 16s - loss: 0.2482 - accuracy: 0.9151 - precision: 0.8968 - recall: 0.9388 - auc: 0.9570
# Batch Number 219 the model has a loss of 0.24801340699195862
#
# Batch Number 220 the model has a loss of 0.24756531417369843
# 220/517 [===========>..................] - ETA: 16s - loss: 0.2476 - accuracy: 0.9156 - precision: 0.8975 - recall: 0.9391 - auc: 0.9571
# Batch Number 221 the model has a loss of 0.24709348380565643
#
# Batch Number 222 the model has a loss of 0.24698159098625183
# 222/517 [===========>..................] - ETA: 16s - loss: 0.2470 - accuracy: 0.9158 - precision: 0.8983 - recall: 0.9386 - auc: 0.9574
# Batch Number 223 the model has a loss of 0.2468976229429245
# 223/517 [===========>..................] - ETA: 16s - loss: 0.2469 - accuracy: 0.9158 - precision: 0.8980 - recall: 0.9389 - auc: 0.9574
# Batch Number 224 the model has a loss of 0.24752090871334076
#
# Batch Number 225 the model has a loss of 0.24868720769882202
# 225/517 [============>.................] - ETA: 16s - loss: 0.2487 - accuracy: 0.9154 - precision: 0.8987 - recall: 0.9376 - auc: 0.9569
# Batch Number 226 the model has a loss of 0.2481306940317154
#
# Batch Number 227 the model has a loss of 0.24838221073150635
# 227/517 [============>.................] - ETA: 16s - loss: 0.2484 - accuracy: 0.9153 - precision: 0.8981 - recall: 0.9377 - auc: 0.9572
# Batch Number 228 the model has a loss of 0.24864043295383453
# 228/517 [============>.................] - ETA: 15s - loss: 0.2486 - accuracy: 0.9152 - precision: 0.8977 - recall: 0.9377 - auc: 0.9572
# Batch Number 229 the model has a loss of 0.24903514981269836
# 229/517 [============>.................] - ETA: 15s - loss: 0.2490 - accuracy: 0.9150 - precision: 0.8974 - recall: 0.9377 - auc: 0.9570
# Batch Number 230 the model has a loss of 0.2481726109981537
#
# Batch Number 231 the model has a loss of 0.24856436252593994
# 231/517 [============>.................] - ETA: 15s - loss: 0.2486 - accuracy: 0.9152 - precision: 0.8975 - recall: 0.9379 - auc: 0.9571
# Batch Number 232 the model has a loss of 0.24872690439224243
# 232/517 [============>.................] - ETA: 15s - loss: 0.2487 - accuracy: 0.9150 - precision: 0.8972 - recall: 0.9379 - auc: 0.9571
# Batch Number 233 the model has a loss of 0.24903957545757294
# 233/517 [============>.................] - ETA: 15s - loss: 0.2490 - accuracy: 0.9148 - precision: 0.8971 - recall: 0.9377 - auc: 0.9571
# Batch Number 234 the model has a loss of 0.24856244027614594
#
# Batch Number 235 the model has a loss of 0.2487482875585556
# 235/517 [============>.................] - ETA: 15s - loss: 0.2487 - accuracy: 0.9149 - precision: 0.8972 - recall: 0.9377 - auc: 0.9572
# Batch Number 236 the model has a loss of 0.2487310916185379
#
# Batch Number 237 the model has a loss of 0.24897578358650208
# 237/517 [============>.................] - ETA: 15s - loss: 0.2490 - accuracy: 0.9148 - precision: 0.8971 - recall: 0.9377 - auc: 0.9571
# Batch Number 238 the model has a loss of 0.24825693666934967
#
# Batch Number 239 the model has a loss of 0.24794189631938934
# 239/517 [============>.................] - ETA: 15s - loss: 0.2479 - accuracy: 0.9153 - precision: 0.8980 - recall: 0.9378 - auc: 0.9574
# Batch Number 240 the model has a loss of 0.24790020287036896
# 240/517 [============>.................] - ETA: 15s - loss: 0.2479 - accuracy: 0.9152 - precision: 0.8977 - recall: 0.9380 - auc: 0.9574
# Batch Number 241 the model has a loss of 0.2477618157863617
# 241/517 [============>.................] - ETA: 15s - loss: 0.2478 - accuracy: 0.9153 - precision: 0.8975 - recall: 0.9381 - auc: 0.9574
# Batch Number 242 the model has a loss of 0.2476179450750351
# 242/517 [=============>................] - ETA: 15s - loss: 0.2476 - accuracy: 0.9153 - precision: 0.8974 - recall: 0.9381 - auc: 0.9575
# Batch Number 243 the model has a loss of 0.24804221093654633
#
# Batch Number 244 the model has a loss of 0.24735027551651
# 244/517 [=============>................] - ETA: 15s - loss: 0.2474 - accuracy: 0.9156 - precision: 0.8981 - recall: 0.9382 - auc: 0.9575
# Batch Number 245 the model has a loss of 0.2471645623445511
#
# Batch Number 246 the model has a loss of 0.24729643762111664
# 246/517 [=============>................] - ETA: 14s - loss: 0.2473 - accuracy: 0.9157 - precision: 0.8983 - recall: 0.9383 - auc: 0.9575
# Batch Number 247 the model has a loss of 0.24656592309474945
# 247/517 [=============>................] - ETA: 14s - loss: 0.2466 - accuracy: 0.9160 - precision: 0.8986 - recall: 0.9385 - auc: 0.9578
# Batch Number 248 the model has a loss of 0.2461782693862915
# 248/517 [=============>................] - ETA: 14s - loss: 0.2462 - accuracy: 0.9162 - precision: 0.8989 - recall: 0.9384 - auc: 0.9579
# Batch Number 249 the model has a loss of 0.2459179013967514
# 249/517 [=============>................] - ETA: 14s - loss: 0.2459 - accuracy: 0.9163 - precision: 0.8990 - recall: 0.9384 - auc: 0.9580
# Batch Number 250 the model has a loss of 0.2453910857439041
# 250/517 [=============>................] - ETA: 14s - loss: 0.2454 - accuracy: 0.9166 - precision: 0.8995 - recall: 0.9387 - auc: 0.9582
# Batch Number 251 the model has a loss of 0.24551136791706085
# 251/517 [=============>................] - ETA: 14s - loss: 0.2455 - accuracy: 0.9165 - precision: 0.8997 - recall: 0.9383 - auc: 0.9582
# Batch Number 252 the model has a loss of 0.2451852262020111
# 252/517 [=============>................] - ETA: 14s - loss: 0.2452 - accuracy: 0.9167 - precision: 0.8998 - recall: 0.9385 - auc: 0.9582
# Batch Number 253 the model has a loss of 0.24549564719200134
# 253/517 [=============>................] - ETA: 14s - loss: 0.2455 - accuracy: 0.9165 - precision: 0.8997 - recall: 0.9382 - auc: 0.9581
# Batch Number 254 the model has a loss of 0.24507153034210205
# 254/517 [=============>................] - ETA: 14s - loss: 0.2451 - accuracy: 0.9166 - precision: 0.8997 - recall: 0.9381 - auc: 0.9583
# Batch Number 255 the model has a loss of 0.24477402865886688
# 255/517 [=============>................] - ETA: 14s - loss: 0.2448 - accuracy: 0.9165 - precision: 0.8999 - recall: 0.9379 - auc: 0.9584
# Batch Number 256 the model has a loss of 0.24428699910640717
# 256/517 [=============>................] - ETA: 14s - loss: 0.2443 - accuracy: 0.9167 - precision: 0.9000 - recall: 0.9381 - auc: 0.9586
# Batch Number 257 the model has a loss of 0.24440626800060272
# 257/517 [=============>................] - ETA: 14s - loss: 0.2444 - accuracy: 0.9166 - precision: 0.8995 - recall: 0.9384 - auc: 0.9586
# Batch Number 258 the model has a loss of 0.2442568838596344
# 258/517 [=============>................] - ETA: 14s - loss: 0.2443 - accuracy: 0.9165 - precision: 0.8997 - recall: 0.9381 - auc: 0.9587
# Batch Number 259 the model has a loss of 0.2439921796321869
# 259/517 [==============>...............] - ETA: 14s - loss: 0.2440 - accuracy: 0.9165 - precision: 0.8998 - recall: 0.9379 - auc: 0.9588
# Batch Number 260 the model has a loss of 0.2438645362854004
# 260/517 [==============>...............] - ETA: 14s - loss: 0.2439 - accuracy: 0.9165 - precision: 0.8997 - recall: 0.9379 - auc: 0.9589
# Batch Number 261 the model has a loss of 0.2436681091785431
# 261/517 [==============>...............] - ETA: 14s - loss: 0.2437 - accuracy: 0.9165 - precision: 0.8997 - recall: 0.9381 - auc: 0.9589
# Batch Number 262 the model has a loss of 0.24392883479595184
# 262/517 [==============>...............] - ETA: 14s - loss: 0.2439 - accuracy: 0.9165 - precision: 0.8995 - recall: 0.9381 - auc: 0.9588
# Batch Number 263 the model has a loss of 0.24338507652282715
# 263/517 [==============>...............] - ETA: 14s - loss: 0.2434 - accuracy: 0.9167 - precision: 0.8999 - recall: 0.9381 - auc: 0.9589
# Batch Number 264 the model has a loss of 0.24309909343719482
# 264/517 [==============>...............] - ETA: 14s - loss: 0.2431 - accuracy: 0.9165 - precision: 0.8994 - recall: 0.9383 - auc: 0.9591
# Batch Number 265 the model has a loss of 0.24322187900543213
# 265/517 [==============>...............] - ETA: 14s - loss: 0.2432 - accuracy: 0.9166 - precision: 0.8995 - recall: 0.9383 - auc: 0.9590
# Batch Number 266 the model has a loss of 0.24320760369300842
# 266/517 [==============>...............] - ETA: 14s - loss: 0.2432 - accuracy: 0.9166 - precision: 0.9000 - recall: 0.9379 - auc: 0.9590
# Batch Number 267 the model has a loss of 0.24304533004760742
#
# Batch Number 268 the model has a loss of 0.24331264197826385
# 268/517 [==============>...............] - ETA: 13s - loss: 0.2433 - accuracy: 0.9166 - precision: 0.8997 - recall: 0.9381 - auc: 0.9587
# Batch Number 269 the model has a loss of 0.24327191710472107
# 269/517 [==============>...............] - ETA: 13s - loss: 0.2433 - accuracy: 0.9166 - precision: 0.9001 - recall: 0.9377 - auc: 0.9588
# Batch Number 270 the model has a loss of 0.2426758110523224
#
# Batch Number 271 the model has a loss of 0.24272997677326202
# 271/517 [==============>...............] - ETA: 13s - loss: 0.2427 - accuracy: 0.9169 - precision: 0.9007 - recall: 0.9377 - auc: 0.9590
# Batch Number 272 the model has a loss of 0.24265645444393158
#
# Batch Number 273 the model has a loss of 0.2425958514213562
# 273/517 [==============>...............] - ETA: 13s - loss: 0.2426 - accuracy: 0.9170 - precision: 0.9008 - recall: 0.9380 - auc: 0.9589
# Batch Number 274 the model has a loss of 0.24232235550880432
# 274/517 [==============>...............] - ETA: 13s - loss: 0.2423 - accuracy: 0.9171 - precision: 0.9007 - recall: 0.9382 - auc: 0.9590
# Batch Number 275 the model has a loss of 0.24250826239585876
#
# Batch Number 276 the model has a loss of 0.24215452373027802
# 276/517 [===============>..............] - ETA: 13s - loss: 0.2422 - accuracy: 0.9171 - precision: 0.9008 - recall: 0.9382 - auc: 0.9590
# Batch Number 277 the model has a loss of 0.2423344999551773
#
# Batch Number 278 the model has a loss of 0.2418881207704544
# 278/517 [===============>..............] - ETA: 13s - loss: 0.2419 - accuracy: 0.9172 - precision: 0.9004 - recall: 0.9386 - auc: 0.9591
# Batch Number 279 the model has a loss of 0.24179312586784363
#
# Batch Number 280 the model has a loss of 0.24178382754325867
# 280/517 [===============>..............] - ETA: 13s - loss: 0.2418 - accuracy: 0.9171 - precision: 0.9000 - recall: 0.9387 - auc: 0.9592
# Batch Number 281 the model has a loss of 0.2414964884519577
# 281/517 [===============>..............] - ETA: 13s - loss: 0.2415 - accuracy: 0.9171 - precision: 0.9004 - recall: 0.9385 - auc: 0.9593
# Batch Number 282 the model has a loss of 0.24101293087005615
#
# Batch Number 283 the model has a loss of 0.24053482711315155
# 283/517 [===============>..............] - ETA: 13s - loss: 0.2405 - accuracy: 0.9175 - precision: 0.9007 - recall: 0.9390 - auc: 0.9596
# Batch Number 284 the model has a loss of 0.24030491709709167
#
# Batch Number 285 the model has a loss of 0.24048550426959991
# 285/517 [===============>..............] - ETA: 12s - loss: 0.2405 - accuracy: 0.9174 - precision: 0.9006 - recall: 0.9390 - auc: 0.9596
# Batch Number 286 the model has a loss of 0.24013927578926086
#
# Batch Number 287 the model has a loss of 0.2404801845550537
# 287/517 [===============>..............] - ETA: 12s - loss: 0.2405 - accuracy: 0.9176 - precision: 0.9004 - recall: 0.9394 - auc: 0.9594
# Batch Number 288 the model has a loss of 0.24020259082317352
# 288/517 [===============>..............] - ETA: 12s - loss: 0.2402 - accuracy: 0.9178 - precision: 0.9008 - recall: 0.9394 - auc: 0.9595
# Batch Number 289 the model has a loss of 0.23972785472869873
# 289/517 [===============>..............] - ETA: 12s - loss: 0.2397 - accuracy: 0.9180 - precision: 0.9010 - recall: 0.9395 - auc: 0.9597
# Batch Number 290 the model has a loss of 0.23945534229278564
# 290/517 [===============>..............] - ETA: 12s - loss: 0.2395 - accuracy: 0.9182 - precision: 0.9011 - recall: 0.9397 - auc: 0.9598
# Batch Number 291 the model has a loss of 0.23909597098827362
#
# Batch Number 292 the model has a loss of 0.2386135756969452
# 292/517 [===============>..............] - ETA: 12s - loss: 0.2386 - accuracy: 0.9186 - precision: 0.9013 - recall: 0.9401 - auc: 0.9600
# Batch Number 293 the model has a loss of 0.238888218998909
# 293/517 [================>.............] - ETA: 12s - loss: 0.2389 - accuracy: 0.9187 - precision: 0.9017 - recall: 0.9401 - auc: 0.9599
# Batch Number 294 the model has a loss of 0.23897387087345123
# 294/517 [================>.............] - ETA: 12s - loss: 0.2390 - accuracy: 0.9188 - precision: 0.9019 - recall: 0.9402 - auc: 0.9599
# Batch Number 295 the model has a loss of 0.23900744318962097
# 295/517 [================>.............] - ETA: 12s - loss: 0.2390 - accuracy: 0.9187 - precision: 0.9018 - recall: 0.9401 - auc: 0.9598
# Batch Number 296 the model has a loss of 0.23952393233776093
#
# Batch Number 297 the model has a loss of 0.24021965265274048
# 297/517 [================>.............] - ETA: 12s - loss: 0.2402 - accuracy: 0.9182 - precision: 0.9009 - recall: 0.9398 - auc: 0.9594
# Batch Number 298 the model has a loss of 0.24019064009189606
#
# Batch Number 299 the model has a loss of 0.24021242558956146
# 299/517 [================>.............] - ETA: 12s - loss: 0.2402 - accuracy: 0.9183 - precision: 0.9011 - recall: 0.9398 - auc: 0.9594
# Batch Number 300 the model has a loss of 0.2398877739906311
# 300/517 [================>.............] - ETA: 11s - loss: 0.2399 - accuracy: 0.9183 - precision: 0.9012 - recall: 0.9399 - auc: 0.9595
# Batch Number 301 the model has a loss of 0.24003782868385315
#
# Batch Number 302 the model has a loss of 0.23970238864421844
# 302/517 [================>.............] - ETA: 11s - loss: 0.2397 - accuracy: 0.9185 - precision: 0.9017 - recall: 0.9397 - auc: 0.9596
# Batch Number 303 the model has a loss of 0.2393595576286316
#
# Batch Number 304 the model has a loss of 0.23962025344371796
# 304/517 [================>.............] - ETA: 11s - loss: 0.2396 - accuracy: 0.9184 - precision: 0.9021 - recall: 0.9391 - auc: 0.9596
# Batch Number 305 the model has a loss of 0.23943623900413513
# 305/517 [================>.............] - ETA: 11s - loss: 0.2394 - accuracy: 0.9185 - precision: 0.9021 - recall: 0.9392 - auc: 0.9597
# Batch Number 306 the model has a loss of 0.2396266609430313
#
# Batch Number 307 the model has a loss of 0.23938456177711487
# 307/517 [================>.............] - ETA: 11s - loss: 0.2394 - accuracy: 0.9184 - precision: 0.9014 - recall: 0.9395 - auc: 0.9597
# Batch Number 308 the model has a loss of 0.2392445057630539
# 308/517 [================>.............] - ETA: 11s - loss: 0.2392 - accuracy: 0.9184 - precision: 0.9013 - recall: 0.9397 - auc: 0.9598
# Batch Number 309 the model has a loss of 0.2392105609178543
# ...
# Batch Number 428 the model has a loss of 0.2368236929178238
# 428/517 [=======================>......] - ETA: 5s - loss: 0.2368 - accuracy: 0.9193 - precision: 0.9057 - recall: 0.9362 - auc: 0.9606
# Batch Number 429 the model has a loss of 0.23699866235256195
# 429/517 [=======================>......] - ETA: 5s - loss: 0.2370 - accuracy: 0.9193 - precision: 0.9057 - recall: 0.9361 - auc: 0.9606
# Batch Number 430 the model has a loss of 0.23711052536964417
#
# Batch Number 431 the model has a loss of 0.23691904544830322
# 431/517 [========================>.....] - ETA: 5s - loss: 0.2369 - accuracy: 0.9193 - precision: 0.9055 - recall: 0.9363 - auc: 0.9606
# Batch Number 432 the model has a loss of 0.2372826188802719
# 432/517 [========================>.....] - ETA: 5s - loss: 0.2373 - accuracy: 0.9193 - precision: 0.9057 - recall: 0.9363 - auc: 0.9605
# Batch Number 433 the model has a loss of 0.23748138546943665
#
# Batch Number 434 the model has a loss of 0.23722733557224274
# 434/517 [========================>.....] - ETA: 4s - loss: 0.2372 - accuracy: 0.9194 - precision: 0.9060 - recall: 0.9360 - auc: 0.9605
# Batch Number 435 the model has a loss of 0.2374042421579361
# 435/517 [========================>.....] - ETA: 4s - loss: 0.2374 - accuracy: 0.9193 - precision: 0.9059 - recall: 0.9360 - auc: 0.9605
# Batch Number 436 the model has a loss of 0.23698113858699799
#
# Batch Number 437 the model has a loss of 0.23714148998260498
# 437/517 [========================>.....] - ETA: 4s - loss: 0.2371 - accuracy: 0.9194 - precision: 0.9061 - recall: 0.9360 - auc: 0.9605
# Batch Number 438 the model has a loss of 0.23730604350566864
#
# Batch Number 439 the model has a loss of 0.2371143102645874
# 439/517 [========================>.....] - ETA: 4s - loss: 0.2371 - accuracy: 0.9193 - precision: 0.9058 - recall: 0.9360 - auc: 0.9606
# Batch Number 440 the model has a loss of 0.23683562874794006
# 440/517 [========================>.....] - ETA: 4s - loss: 0.2368 - accuracy: 0.9194 - precision: 0.9059 - recall: 0.9361 - auc: 0.9607
# Batch Number 441 the model has a loss of 0.236788809299469
# 441/517 [========================>.....] - ETA: 4s - loss: 0.2368 - accuracy: 0.9194 - precision: 0.9060 - recall: 0.9362 - auc: 0.9607
# Batch Number 442 the model has a loss of 0.2363782674074173
# 442/517 [========================>.....] - ETA: 4s - loss: 0.2364 - accuracy: 0.9196 - precision: 0.9062 - recall: 0.9363 - auc: 0.9609
# Batch Number 443 the model has a loss of 0.23657183349132538
# 443/517 [========================>.....] - ETA: 4s - loss: 0.2366 - accuracy: 0.9196 - precision: 0.9060 - recall: 0.9364 - auc: 0.9608
# Batch Number 444 the model has a loss of 0.23657028377056122
# 444/517 [========================>.....] - ETA: 4s - loss: 0.2366 - accuracy: 0.9195 - precision: 0.9058 - recall: 0.9364 - auc: 0.9608
# Batch Number 445 the model has a loss of 0.23651248216629028
# 445/517 [========================>.....] - ETA: 4s - loss: 0.2365 - accuracy: 0.9195 - precision: 0.9059 - recall: 0.9364 - auc: 0.9608
# Batch Number 446 the model has a loss of 0.23642976582050323
# 446/517 [========================>.....] - ETA: 4s - loss: 0.2364 - accuracy: 0.9195 - precision: 0.9059 - recall: 0.9362 - auc: 0.9609
# Batch Number 447 the model has a loss of 0.2360740453004837
# 447/517 [========================>.....] - ETA: 4s - loss: 0.2361 - accuracy: 0.9197 - precision: 0.9061 - recall: 0.9364 - auc: 0.9610
# Batch Number 448 the model has a loss of 0.2363816350698471
# 448/517 [========================>.....] - ETA: 4s - loss: 0.2364 - accuracy: 0.9196 - precision: 0.9061 - recall: 0.9363 - auc: 0.9608
# Batch Number 449 the model has a loss of 0.23630985617637634
# 449/517 [=========================>....] - ETA: 4s - loss: 0.2363 - accuracy: 0.9196 - precision: 0.9060 - recall: 0.9364 - auc: 0.9608
# Batch Number 450 the model has a loss of 0.2361648678779602
# 450/517 [=========================>....] - ETA: 3s - loss: 0.2362 - accuracy: 0.9197 - precision: 0.9061 - recall: 0.9366 - auc: 0.9609
# Batch Number 451 the model has a loss of 0.23605883121490479
# 451/517 [=========================>....] - ETA: 3s - loss: 0.2361 - accuracy: 0.9198 - precision: 0.9061 - recall: 0.9367 - auc: 0.9609
# Batch Number 452 the model has a loss of 0.23590980470180511
# 452/517 [=========================>....] - ETA: 3s - loss: 0.2359 - accuracy: 0.9198 - precision: 0.9061 - recall: 0.9367 - auc: 0.9610
# Batch Number 453 the model has a loss of 0.23582898080348969
#
# Batch Number 454 the model has a loss of 0.23577679693698883
# 454/517 [=========================>....] - ETA: 3s - loss: 0.2358 - accuracy: 0.9199 - precision: 0.9064 - recall: 0.9365 - auc: 0.9610
# Batch Number 455 the model has a loss of 0.2356734722852707
# 455/517 [=========================>....] - ETA: 3s - loss: 0.2357 - accuracy: 0.9199 - precision: 0.9065 - recall: 0.9366 - auc: 0.9611
# Batch Number 456 the model has a loss of 0.23574747145175934
# 456/517 [=========================>....] - ETA: 3s - loss: 0.2357 - accuracy: 0.9199 - precision: 0.9067 - recall: 0.9364 - auc: 0.9611
# Batch Number 457 the model has a loss of 0.23541250824928284
# 457/517 [=========================>....] - ETA: 3s - loss: 0.2354 - accuracy: 0.9200 - precision: 0.9069 - recall: 0.9364 - auc: 0.9612
# Batch Number 458 the model has a loss of 0.2351299226284027
# 458/517 [=========================>....] - ETA: 3s - loss: 0.2351 - accuracy: 0.9201 - precision: 0.9071 - recall: 0.9364 - auc: 0.9613
# Batch Number 459 the model has a loss of 0.2350115180015564
# 459/517 [=========================>....] - ETA: 3s - loss: 0.2350 - accuracy: 0.9202 - precision: 0.9071 - recall: 0.9365 - auc: 0.9613
# Batch Number 460 the model has a loss of 0.2353309988975525
# 460/517 [=========================>....] - ETA: 3s - loss: 0.2353 - accuracy: 0.9202 - precision: 0.9070 - recall: 0.9364 - auc: 0.9611
# Batch Number 461 the model has a loss of 0.23497603833675385
# 461/517 [=========================>....] - ETA: 3s - loss: 0.2350 - accuracy: 0.9203 - precision: 0.9072 - recall: 0.9366 - auc: 0.9612
# Batch Number 462 the model has a loss of 0.23454587161540985
# 462/517 [=========================>....] - ETA: 3s - loss: 0.2345 - accuracy: 0.9205 - precision: 0.9074 - recall: 0.9367 - auc: 0.9614
# Batch Number 463 the model has a loss of 0.23473650217056274
# 463/517 [=========================>....] - ETA: 3s - loss: 0.2347 - accuracy: 0.9205 - precision: 0.9073 - recall: 0.9367 - auc: 0.9613
# Batch Number 464 the model has a loss of 0.23456767201423645
# 464/517 [=========================>....] - ETA: 3s - loss: 0.2346 - accuracy: 0.9206 - precision: 0.9074 - recall: 0.9368 - auc: 0.9613
# Batch Number 465 the model has a loss of 0.23443181812763214
# 465/517 [=========================>....] - ETA: 3s - loss: 0.2344 - accuracy: 0.9206 - precision: 0.9076 - recall: 0.9367 - auc: 0.9614
# Batch Number 466 the model has a loss of 0.2346014678478241
# 466/517 [==========================>...] - ETA: 3s - loss: 0.2346 - accuracy: 0.9205 - precision: 0.9073 - recall: 0.9369 - auc: 0.9613
# Batch Number 467 the model has a loss of 0.23424221575260162
# 467/517 [==========================>...] - ETA: 2s - loss: 0.2342 - accuracy: 0.9206 - precision: 0.9074 - recall: 0.9370 - auc: 0.9615
# Batch Number 468 the model has a loss of 0.23397943377494812
# 468/517 [==========================>...] - ETA: 2s - loss: 0.2340 - accuracy: 0.9207 - precision: 0.9074 - recall: 0.9371 - auc: 0.9615
# Batch Number 469 the model has a loss of 0.2338363081216812
# 469/517 [==========================>...] - ETA: 2s - loss: 0.2338 - accuracy: 0.9207 - precision: 0.9072 - recall: 0.9372 - auc: 0.9616
# Batch Number 470 the model has a loss of 0.2340930551290512
# 470/517 [==========================>...] - ETA: 2s - loss: 0.2341 - accuracy: 0.9206 - precision: 0.9071 - recall: 0.9372 - auc: 0.9615
# Batch Number 471 the model has a loss of 0.2341090738773346
#
# Batch Number 472 the model has a loss of 0.23387092351913452
# 472/517 [==========================>...] - ETA: 2s - loss: 0.2339 - accuracy: 0.9206 - precision: 0.9073 - recall: 0.9370 - auc: 0.9616
# Batch Number 473 the model has a loss of 0.23362834751605988
# 473/517 [==========================>...] - ETA: 2s - loss: 0.2336 - accuracy: 0.9207 - precision: 0.9074 - recall: 0.9371 - auc: 0.9617
# Batch Number 474 the model has a loss of 0.23374222218990326
# 474/517 [==========================>...] - ETA: 2s - loss: 0.2337 - accuracy: 0.9207 - precision: 0.9072 - recall: 0.9372 - auc: 0.9616
# Batch Number 475 the model has a loss of 0.233673557639122
# 475/517 [==========================>...] - ETA: 2s - loss: 0.2337 - accuracy: 0.9207 - precision: 0.9071 - recall: 0.9373 - auc: 0.9616
# Batch Number 476 the model has a loss of 0.23340056836605072
#
# Batch Number 477 the model has a loss of 0.23322300612926483
# 477/517 [==========================>...] - ETA: 2s - loss: 0.2332 - accuracy: 0.9209 - precision: 0.9075 - recall: 0.9374 - auc: 0.9617
# Batch Number 478 the model has a loss of 0.2332385927438736
# 478/517 [==========================>...] - ETA: 2s - loss: 0.2332 - accuracy: 0.9208 - precision: 0.9075 - recall: 0.9373 - auc: 0.9617
# Batch Number 479 the model has a loss of 0.23319101333618164
# 479/517 [==========================>...] - ETA: 2s - loss: 0.2332 - accuracy: 0.9209 - precision: 0.9075 - recall: 0.9374 - auc: 0.9617
# Batch Number 480 the model has a loss of 0.23286156356334686
# 480/517 [==========================>...] - ETA: 2s - loss: 0.2329 - accuracy: 0.9211 - precision: 0.9076 - recall: 0.9375 - auc: 0.9618
# Batch Number 481 the model has a loss of 0.23263435065746307
# 481/517 [==========================>...] - ETA: 2s - loss: 0.2326 - accuracy: 0.9212 - precision: 0.9077 - recall: 0.9376 - auc: 0.9619
# Batch Number 482 the model has a loss of 0.2329263985157013
# 482/517 [==========================>...] - ETA: 2s - loss: 0.2329 - accuracy: 0.9212 - precision: 0.9077 - recall: 0.9376 - auc: 0.9618
# Batch Number 483 the model has a loss of 0.23279820382595062
# 483/517 [===========================>..] - ETA: 2s - loss: 0.2328 - accuracy: 0.9213 - precision: 0.9078 - recall: 0.9377 - auc: 0.9618
# Batch Number 484 the model has a loss of 0.23255155980587006
# 484/517 [===========================>..] - ETA: 1s - loss: 0.2326 - accuracy: 0.9213 - precision: 0.9077 - recall: 0.9379 - auc: 0.9619
# Batch Number 485 the model has a loss of 0.2321394979953766
# 485/517 [===========================>..] - ETA: 1s - loss: 0.2321 - accuracy: 0.9215 - precision: 0.9079 - recall: 0.9380 - auc: 0.9620
# Batch Number 486 the model has a loss of 0.2320471704006195
# 486/517 [===========================>..] - ETA: 1s - loss: 0.2320 - accuracy: 0.9215 - precision: 0.9080 - recall: 0.9380 - auc: 0.9620
# Batch Number 487 the model has a loss of 0.2317667305469513
# 487/517 [===========================>..] - ETA: 1s - loss: 0.2318 - accuracy: 0.9216 - precision: 0.9081 - recall: 0.9380 - auc: 0.9621
# Batch Number 488 the model has a loss of 0.232011079788208
# 488/517 [===========================>..] - ETA: 1s - loss: 0.2320 - accuracy: 0.9215 - precision: 0.9081 - recall: 0.9379 - auc: 0.9621
# Batch Number 489 the model has a loss of 0.23225198686122894
# 489/517 [===========================>..] - ETA: 1s - loss: 0.2323 - accuracy: 0.9214 - precision: 0.9079 - recall: 0.9379 - auc: 0.9620
# Batch Number 490 the model has a loss of 0.232110396027565
#
# Batch Number 491 the model has a loss of 0.23217935860157013
# 491/517 [===========================>..] - ETA: 1s - loss: 0.2322 - accuracy: 0.9215 - precision: 0.9082 - recall: 0.9379 - auc: 0.9620
# Batch Number 492 the model has a loss of 0.23243385553359985
# 492/517 [===========================>..] - ETA: 1s - loss: 0.2324 - accuracy: 0.9214 - precision: 0.9081 - recall: 0.9379 - auc: 0.9619
# Batch Number 493 the model has a loss of 0.23255255818367004
# 493/517 [===========================>..] - ETA: 1s - loss: 0.2326 - accuracy: 0.9214 - precision: 0.9080 - recall: 0.9379 - auc: 0.9618
# Batch Number 494 the model has a loss of 0.23268979787826538
# 494/517 [===========================>..] - ETA: 1s - loss: 0.2327 - accuracy: 0.9214 - precision: 0.9080 - recall: 0.9378 - auc: 0.9617
# Batch Number 495 the model has a loss of 0.23252816498279572
# 495/517 [===========================>..] - ETA: 1s - loss: 0.2325 - accuracy: 0.9214 - precision: 0.9081 - recall: 0.9378 - auc: 0.9618
# Batch Number 496 the model has a loss of 0.23304229974746704
#
# Batch Number 497 the model has a loss of 0.2332697957754135
# 497/517 [===========================>..] - ETA: 1s - loss: 0.2333 - accuracy: 0.9212 - precision: 0.9077 - recall: 0.9376 - auc: 0.9616
# Batch Number 498 the model has a loss of 0.23311114311218262
#
# Batch Number 499 the model has a loss of 0.23275549709796906
# 499/517 [===========================>..] - ETA: 1s - loss: 0.2328 - accuracy: 0.9213 - precision: 0.9080 - recall: 0.9376 - auc: 0.9617
# Batch Number 500 the model has a loss of 0.23236799240112305
# 500/517 [============================>.] - ETA: 1s - loss: 0.2324 - accuracy: 0.9215 - precision: 0.9082 - recall: 0.9377 - auc: 0.9619
# Batch Number 501 the model has a loss of 0.2325492650270462
#
# Batch Number 502 the model has a loss of 0.23229311406612396
# 502/517 [============================>.] - ETA: 0s - loss: 0.2323 - accuracy: 0.9215 - precision: 0.9082 - recall: 0.9377 - auc: 0.9619
# Batch Number 503 the model has a loss of 0.23241674900054932
# 503/517 [============================>.] - ETA: 0s - loss: 0.2324 - accuracy: 0.9215 - precision: 0.9083 - recall: 0.9378 - auc: 0.9618
# Batch Number 504 the model has a loss of 0.23249909281730652
# 504/517 [============================>.] - ETA: 0s - loss: 0.2325 - accuracy: 0.9215 - precision: 0.9084 - recall: 0.9376 - auc: 0.9618
# Batch Number 505 the model has a loss of 0.23229438066482544
# 505/517 [============================>.] - ETA: 0s - loss: 0.2323 - accuracy: 0.9215 - precision: 0.9083 - recall: 0.9377 - auc: 0.9619
# Batch Number 506 the model has a loss of 0.23210488259792328
# 506/517 [============================>.] - ETA: 0s - loss: 0.2321 - accuracy: 0.9216 - precision: 0.9084 - recall: 0.9378 - auc: 0.9619
# Batch Number 507 the model has a loss of 0.2319614142179489
#
# Batch Number 508 the model has a loss of 0.2324092537164688
# 508/517 [============================>.] - ETA: 0s - loss: 0.2324 - accuracy: 0.9216 - precision: 0.9087 - recall: 0.9377 - auc: 0.9618
# Batch Number 509 the model has a loss of 0.23222167789936066
#
# Batch Number 510 the model has a loss of 0.2323063611984253
# 510/517 [============================>.] - ETA: 0s - loss: 0.2323 - accuracy: 0.9216 - precision: 0.9084 - recall: 0.9379 - auc: 0.9618
# Batch Number 511 the model has a loss of 0.23225288093090057
#
# Batch Number 512 the model has a loss of 0.23212546110153198
# 512/517 [============================>.] - ETA: 0s - loss: 0.2321 - accuracy: 0.9218 - precision: 0.9085 - recall: 0.9382 - auc: 0.9618
# Batch Number 513 the model has a loss of 0.23202525079250336
# 513/517 [============================>.] - ETA: 0s - loss: 0.2320 - accuracy: 0.9218 - precision: 0.9084 - recall: 0.9383 - auc: 0.9618
# Batch Number 514 the model has a loss of 0.23212498426437378
# 514/517 [============================>.] - ETA: 0s - loss: 0.2321 - accuracy: 0.9218 - precision: 0.9082 - recall: 0.9384 - auc: 0.9618
# Batch Number 515 the model has a loss of 0.23174640536308289
# 515/517 [============================>.] - ETA: 0s - loss: 0.2317 - accuracy: 0.9219 - precision: 0.9084 - recall: 0.9385 - auc: 0.9619
# Batch Number 516 the model has a loss of 0.2323451191186905
# 516/517 [============================>.] - ETA: 0s - loss: 0.2323 - accuracy: 0.9218 - precision: 0.9080 - recall: 0.9384 - auc: 0.9616
# Batch Number 517 the model has a loss of 0.23264683783054352
#
# Epoch Number 1 the model has a loss of 0.23264683783054352
# 517/517 [==============================] - 56s 99ms/step - loss: 0.2326 - accuracy: 0.9217 - precision: 0.9078 - recall: 0.9385 - auc: 0.9615 - val_loss: 0.2942 - val_accuracy: 0.9156 - val_precision: 0.8672 - val_recall: 0.9819 - val_auc: 0.9403

# %% [markdown]
# ### CSVLogger
# Streams epoch results to a CSV file. ***

# %%
csv_callback = tf.keras.callbacks.CSVLogger(
    filename='logs.csv', separator=',', append=False # True
)

# %%
metrics = [BinaryAccuracy(name='accuracy'),
           Precision(name='precision'),
           Recall(name='recall'),
           AUC(name='auc')]
model.compile(optimizer=Adam(learning_rate=0.001),
              loss=BinaryCrossentropy(),
              metrics=metrics)
history = model.fit(train_dataset, validation_data=val_dataset, epochs=1, verbose=1, callbacks = [csv_callback])
# Out:
# 517/517 [==============================] - 51s 91ms/step - loss: 0.1770 - accuracy: 0.9419 - precision: 0.9335 - recall: 0.9514 - auc: 0.9768 - val_loss: 0.2351 - val_accuracy: 0.9289 - val_precision: 0.9115 - val_recall: 0.9504 - val_auc: 0.9558

# %% [markdown]
# ### EarlyStopping
#
# - At certain point the model stops generalizing.
# - Stop training when overfitting occurs. (=when valdiation accuracy does not increase)
# - Stop training automatically!

# %%
es_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', # check on val loss, once it stops reducing, it stop training
    min_delta=0, # 0 => any slightest change is considered drop.
    patience=0, # **epochs with no improvement after which training will be stopped.
                # if 5, 5 successive in/decrease occurs in monitored quantity, it stops.
    verbose=0,
    mode='auto', # min => stop training when monitored quantity decreases
    baseline=None,
    restore_best_weights=False,
    start_from_epoch=0
)

# %%
metrics = [BinaryAccuracy(name='accuracy'),
           Precision(name='precision'),
           Recall(name='recall'),
           AUC(name='auc')]
model.compile(optimizer=Adam(learning_rate=0.001),
              loss=BinaryCrossentropy(),
              metrics=metrics)
history = model.fit(train_dataset, validation_data=val_dataset, epochs=1, verbose=1, callbacks = [es_callback])
